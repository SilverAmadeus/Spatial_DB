# %%
import pandas as pd
import re
import pickle
import io

# %%
from keras.preprocessing.text import Tokenizer
# Out:
# Using TensorFlow backend.

# %%
tokenizer = Tokenizer(num_words=20000,lower=False, filters='!"$%&()*+,-.;<=>?[\\]^_`{|}~\t\n')

# %%
taskFile = './results_sarcasmo.csv'

# %%
def normalizeText(tweet):
    tweet = re.sub(r'#(S|s)arcasm|#(I|i)rony','',tweet)
    tweet = re.sub(r'#SARCASM|#IRONY','',tweet)
    tweet = re.sub(r'https?://t\.co/.(\w|\d)+','http://link', tweet) #tweet link
    tweet = re.sub(r'@.\w*','@',tweet)
    tweet = re.sub(r'#','',tweet)
    return tweet

def buildTokenizer(tweets):
    tokenizer.fit_on_texts(tweets)
    return tokenizer

def text2seq(tweet):
    return tokenizer.texts_to_sequences([tweet])[0] # Return array like [1 2 3] instead of [[1 2 3]]

# %%
def read_ds(ds_list):
    supreme = []
    for tweet in ds_list:
        supreme.append(tweet.split('|',2)[-2:])
    return supreme

# %%
with io.open('corpus_50_50.txt','r',encoding='utf8') as f:
    corpus = f.readlines()

# %%
corpus = read_ds(corpus)
for i in corpus[:10]:
    print (i)
# Out:
# ['1', 'Tengo tantas ganas de comer sopa\n']
# ['1', '@ @ @ @ faltó el ingenioso @ . 😅\n']
# ['0', '@ donde sea pero que se le caiga el pipi charlie charlie\n']
# ['1', '@ Yo ya te sigo, me gustan y tus fotos y el video de hace poco genialisimo  ON\n']
# ['1', '@ @ Ah bueno si, respuesta si jajajajaja\n']
# ['1', 'Partidazo de Noir\n']
# ['1', '@ pero y como es que descubren eso ahora!!\n']
# ['1', 'Más Pymes, cómo se habrá enterado que todos necesitamos un portasandia en la vida, el negociazo!    http://link\n']
# ['0', 'Hablar Con El Como Lo Mas Hermoso Que Hay ,El Que Entiende Mis Visajes Y Yo Los De El ♡.♡\n']
# ['1', 'Hablemos con el Representante. El le responde al pueblo...  http://link\n']

# %%
data = pd.DataFrame(data=corpus,columns=['CATEGORY','TWEET'])

# %%
data.head()
# Out:
#   CATEGORY                                              TWEET
# 0        1                 Tengo tantas ganas de comer sopa\n
# 1        1                 @ @ @ @ faltó el ingenioso @ . 😅\n
# 2        0  @ donde sea pero que se le caiga el pipi charl...
# 3        1  @ Yo ya te sigo, me gustan y tus fotos y el vi...
# 4        1         @ @ Ah bueno si, respuesta si jajajajaja\n

# %%
token = buildTokenizer(data.TWEET)

# %%
token.word_index
# Out:
# {'flamenco': 7080,
#  'Jacobo': 17972,
#  'insólitas': 21133,
#  'concentrarse': 28399,
#  'claudio': 16739,
#  'solucion': 8172,
#  'barquisimetanxs': 14703,
#  'informa': 14916,
#  'Trejo': 16610,
#  'Tienen': 2723,
#  'LaBellayLaBestia': 27564,
#  'taohun': 24476,
#  'Nadal': 6166,
#  'Domingo': 1820,
#  'pure': 13101,
#  'aclara': 19445,
#  'ladilla': 24138,
#  'marley': 9937,
#  'parasito': 23659,
#  'mexico': 5742,
#  'FFVII': 26663,
#  'moda': 1419,
#  'א': 18087,
#  'preparando': 8810,
#  'ton': 27259,
#  'maximo': 5930,
#  'acostaron': 19575,
#  'ocurrencia': 20505,
#  'cogiendo': 12265,
#  '88': 5535,
#  'unirme': 26381,
#  'cel': 1747,
#  'putitos': 22126,
#  'MeDescojonoVivo': 22230,
#  'mercaillo': 21908,
#  'coherente': 4234,
#  'barbie': 21973,
#  'comprometidas': 27054,
#  'autoinvita': 25451,
#  'hanko': 9779,
#  'argumentar': 10805,
#  'playback': 4905,
#  'coloso': 18415,
#  'dinerito': 18574,
#  'teléfonos': 15974,
#  'posee': 27996,
#  'aparece': 1742,
#  'argentinos': 4814,
#  'Benson': 26777,
#  'gustaron': 24217,
#  'podrias': 6273,
#  'Whatsapp': 3055,
#  'nMtvHitCD9': 17995,
#  'culote': 23211,
#  'Humor': 1643,
#  'chavista': 3673,
#  'interés': 1301,
#  'Soviets': 11714,
#  'Asco': 20429,
#  'solos': 17817,
#  'igualita': 5738,
#  'respondais': 12913,
#  'grazas': 22832,
#  'bombaa': 12529,
#  'asique': 4050,
#  'nazi': 11990,
#  'chupando': 7808,
#  'esperare': 8202,
#  'conté': 8712,
#  'Inmejorables': 20871,
#  'Cd': 20204,
#  'orgullodemadre': 23560,
#  'findes': 11098,
#  'Obama': 9677,
#  '11': 2236,
#  'nALV': 12938,
#  'Robert': 28934,
#  'Chope': 3613,
#  'publicada': 28760,
#  'dividida': 21651,
#  'Fede': 5482,
#  'Amigo': 6135,
#  'alcaldes': 29382,
#  'minimas': 26362,
#  'SoyUnaPelotudaMeLlevoPlasticaYMusica': 25272,
#  'FueraChope': 16545,
#  'empeños': 14317,
#  'bloqueados': 22810,
#  'base': 2099,
#  'COMPRENDEMOS': 13507,
#  'paisajeeeeeeee': 26776,
#  'nombrar': 8745,
#  'decepcionas': 24982,
#  'Ui': 15341,
#  'haciéndote': 9932,
#  'Express': 6009,
#  'quiz': 15863,
#  'Mal': 4049,
#  'haaay': 27788,
#  'BIO': 19266,
#  'funesto': 28550,
#  'PreguntasTontas': 24146,
#  'Más': 1164,
#  'batalla': 5567,
#  'GANÓ': 20192,
#  'reservado': 28211,
#  'verguenzaver': 18041,
#  'comenzaba': 12605,
#  'Amiigo/a': 19762,
#  'renear': 19765,
#  'objetivos': 5398,
#  'LPM': 8628,
#  'juntaba': 12908,
#  'publiquen': 5571,
#  'orgasmo😏✌🏻️': 27720,
#  'EXTRAÑO': 12959,
#  'wachin': 13720,
#  'juntas': 4401,
#  'acercando': 22933,
#  'concacaf': 17700,
#  'Sirve': 14966,
#  'amomiciudad': 22886,
#  'institucionales': 25187,
#  'pfff': 8980,
#  'propone': 6110,
#  'CopaAmericaChilegracias': 18085,
#  'WWE': 6500,
#  'sombra': 3795,
#  'volaste': 21204,
#  'Hermosoo': 29065,
#  'instante': 2845,
#  'tipos': 5121,
#  'JAAJAJJA': 18785,
#  'despotricar': 26043,
#  'GANES': 11757,
#  'Estar': 1223,
#  'mañoso': 29461,
#  'Leganes': 7040,
#  'CabreoEnAumento': 10177,
#  'link': 962,
#  'Nestor': 23385,
#  'simpatía': 4313,
#  'formalismos': 19073,
#  'TRIBUTO': 17741,
#  'tortuga': 22329,
#  'ufff': 7973,
#  'épico': 29696,
#  'hayas': 4293,
#  'enemigos': 3408,
#  'escoria': 27450,
#  'tego': 17240,
#  'potoshop': 11650,
#  'hechadas': 21606,
#  '¡Te': 18258,
#  'publis': 15683,
#  'gemela': 5606,
#  'QUEMA': 11430,
#  'hicieran': 25318,
#  'merezco': 7455,
#  'auch': 9985,
#  'plagas': 22601,
#  'presi': 4225,
#  'tocas': 5913,
#  'Circo': 9410,
#  'barriga': 3821,
#  'CUQUINA': 17988,
#  'razón': 572,
#  'cambié': 9098,
#  'CIDH': 12628,
#  'imprimir': 21070,
#  'ayer👌🏼': 26082,
#  'escena': 2517,
#  'ecuatoriana': 7465,
#  'suministros': 25248,
#  'SUPERAN': 13403,
#  '\xa0': 5548,
#  'pibita': 4723,
#  'Humanidades😄': 26993,
#  'arranque': 5918,
#  'auto': 1416,
#  'TyT': 24640,
#  'Colaborador': 5992,
#  'Nacer': 12273,
#  'horaa': 6866,
#  'Re': 3457,
#  'minutos': 632,
#  'Fútbol': 5528,
#  'exquisito': 16325,
#  'Balsamello': 16127,
#  'Leopoldito': 13029,
#  'Pre': 15315,
#  'DHA': 21003,
#  'snapchat': 4550,
#  'QueSeriaMiVidaSin': 22229,
#  'la': 5,
#  'whatssap': 20201,
#  'vitel': 26955,
#  'atacó': 6732,
#  'platica': 5708,
#  'nombraron': 12916,
#  'Aguadilla': 12994,
#  'festejen': 17196,
#  'Voice': 28706,
#  'capitalistas': 19507,
#  '¡Muy': 28700,
#  'escaleras': 6785,
#  'andaluses': 16537,
#  'Ush': 25620,
#  '👏👏👌😤': 26672,
#  'Mujeres': 4021,
#  'NOMBRE': 9475,
#  'SCT': 23188,
#  'APELLIDO': 24536,
#  'Cuarta': 29751,
#  'cabreada': 10338,
#  'luchó': 20874,
#  'GanasDeMatarAumentando': 16921,
#  'tampoco': 734,
#  'robaron': 4679,
#  'meses🙆🏻': 17136,
#  'Simulacro': 28598,
#  'TENDRÁS': 23816,
#  'hambre:33': 17560,
#  'pusiste': 3018,
#  'Destino2015': 23841,
#  'zunguiamigui': 29452,
#  'afónica': 6827,
#  'mejora': 2207,
#  'fortuna': 20607,
#  'Medidas': 29467,
#  'MTVInstaDulce': 25229,
#  'Cabal': 25836,
#  'taxistas': 5124,
#  'Nicole': 9393,
#  'valencias': 23096,
#  'nEstoy': 14501,
#  'perrasas': 27567,
#  'DF': 2594,
#  'Noto': 5333,
#  'dejaban': 24276,
#  'mandaron': 6641,
#  'encantaba': 10829,
#  'Lyfestyle': 17425,
#  '😨': 2922,
#  'manerados': 22128,
#  'peleamos': 5648,
#  'ComicConChile2015': 25840,
#  'musulmana': 8439,
#  'Debería': 3919,
#  '1/4': 22146,
#  'dí': 24900,
#  'Estrada': 13770,
#  'matiassss': 22154,
#  '4ever': 27796,
#  'fail': 9151,
#  'pajaritos': 15798,
#  'corbera': 11871,
#  'haciendo': 270,
#  '40principales': 10921,
#  'Official': 17388,
#  'Valdiviacl': 23395,
#  'Lynda': 14214,
#  'youtuber': 10473,
#  'vivaeldoble': 21896,
#  'volcados': 22123,
#  'Bosa': 27908,
#  'reducen': 23454,
#  'opacaran': 20159,
#  'escandalo': 19890,
#  'instituto': 2637,
#  '😳😱': 25047,
#  'Tumaco': 24168,
#  'pura': 2411,
#  'Bajame': 19050,
#  'Vierneeeeez': 20137,
#  'meeeh': 10062,
#  'alegrón': 29015,
#  'tráficos': 12279,
#  'salia': 6282,
#  'PUEDE': 3149,
#  'Dora': 29412,
#  'Filo': 9478,
#  'ai': 8005,
#  'FUERON': 8825,
#  'Ingles': 5860,
#  'tardado': 12205,
#  'arbitros': 7747,
#  'gracias': 126,
#  'TLs': 24364,
#  'NiallWeLoveYourVoice': 11260,
#  'dient': 23537,
#  'gemelier': 22108,
#  'niganas': 28602,
#  'jugatela': 18324,
#  'cansar': 4462,
#  'rie': 3057,
#  'TATGranada15': 10631,
#  'Zague': 15756,
#  'APOYARÉ': 9492,
#  'ULA': 28329,
#  'terminé🙍': 28902,
#  'nLibre': 13642,
#  'desnuda88': 23753,
#  'monopolio': 25370,
#  'avatar': 15684,
#  'ridiculizar': 16154,
#  'Amigos': 5030,
#  'nGRACIAS': 7980,
#  'desnudo': 24002,
#  'ForzaHorizon2': 14221,
#  'debut': 5765,
#  'criterio': 5214,
#  'devolvértelas': 25972,
#  'Com': 9176,
#  'nViene': 12268,
#  'fingir': 6713,
#  'tia': 5533,
#  'bañador': 23621,
#  'impactantemente': 23705,
#  'estiman': 20762,
#  'hawaiana': 29268,
#  'precisamente': 9474,
#  'PACOtillas': 16493,
#  'aunq': 16123,
#  'despertar💉': 13383,
#  '10min': 6589,
#  'jerarquía': 22790,
#  'amoooo': 28238,
#  'meencantatodo': 14474,
#  '😱😜': 10889,
#  'ipadgames': 8486,
#  'terricolas': 22184,
#  'Deu': 24178,
#  'entretenido': 1851,
#  'migrañas': 9245,
#  'derrota': 4526,
#  'negociosalestilopanista': 24297,
#  'zumbidos': 28533,
#  'FH': 26893,
#  'abriendo': 18030,
#  'Macri': 26405,
#  'contaminar': 16704,
#  'Ayuntamiento': 3916,
#  'horadehonestidad': 16094,
#  'paga': 2937,
#  'comienza': 1980,
#  'descuentazos': 25218,
#  'SOCIALITE': 26273,
#  'dm': 4292,
#  'interesa': 728,
#  'TATUARME': 13417,
#  'murio': 8533,
#  'viviendo': 1598,
#  'Terrible': 4646,
#  'soriana': 16769,
#  'twiteo': 9386,
#  'agüita': 26243,
#  'taquero': 24075,
#  'demencia': 19879,
#  'horaaaaaa': 16724,
#  'importen': 20846,
#  'telefónica': 11040,
#  'traquis': 27726,
#  'Duff': 28844,
#  'audio': 2532,
#  'lagrimasdeSanLorenzo': 17746,
#  'intercambian': 23017,
#  'abarrotados': 26519,
#  'my': 3328,
#  'gilastru': 15196,
#  "d'empresa": 17558,
#  'hippie': 23780,
#  'Gusta': 8124,
#  'deportivos': 11983,
#  '¡El': 11676,
#  'THE': 10127,
#  '100': 706,
#  'extincion': 20064,
#  'amargos': 10625,
#  'fumar': 5375,
#  'chappie': 27727,
#  'Pinochet': 29160,
#  'fallaVan': 15784,
#  'adoroooo': 20752,
#  'shooters': 19564,
#  'raje': 20525,
#  'calidad': 827,
#  'confundidos': 9120,
#  'Reparaciones': 12550,
#  'movil': 1198,
#  'Mamá': 5013,
#  'avergüenzan': 18450,
#  'PRIyPRDSonLoMismo': 4028,
#  'qu': 8337,
#  'creas': 3667,
#  'estética': 15356,
#  '1sola': 11702,
#  'cerebral': 18537,
#  'Did': 17064,
#  'pidamos': 23479,
#  'askmagcult': 26360,
#  'acumulando': 16963,
#  'malditocescobiencontenta😒😡😡': 29409,
#  'LANATA': 19383,
#  'miente': 4320,
#  'farmacéutica': 29225,
#  'trafico': 5931,
#  'lleis': 15775,
#  'Echa': 4132,
#  'peruano': 13567,
#  'guatemaltecos': 13447,
#  'corriera': 22937,
#  'mangonee': 12063,
#  'straight': 22485,
#  'carril': 14411,
#  'mejorrpelelecomotu': 26262,
#  'Tipo': 4290,
#  'clan': 21400,
#  'Nuestros': 10464,
#  'bancan': 7247,
#  'Jobhy': 22436,
#  'EFECTOS': 19189,
#  'ceropaciencia': 15551,
#  'Noel': 6705,
#  'alcanzo': 14361,
#  'Angeles': 7775,
#  'OKEI': 10621,
#  'pajeras': 9463,
#  'quemeamarren': 25024,
#  '😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂': 11318,
#  'TENGANME': 23010,
#  'estudian': 15328,
#  'ALMAS': 28316,
#  'telemundo': 21979,
#  'estas': 149,
#  'recien': 4715,
#  'WeFollowBack': 5552,
#  'mantengan': 24374,
#  'colectivos': 4716,
#  'terminando': 4088,
#  'pilares': 25857,
#  'misterio': 12882,
#  'Cuántas': 24024,
#  'soluciones': 6644,
#  'salsita': 21000,
#  'LavadoraALasSeisDeLaMañana': 27031,
#  'nte': 27070,
#  'demuestras': 24806,
#  'TT': 2051,
#  'Ascazo': 16473,
#  'terribles': 4371,
#  'reproducir': 7068,
#  'cani': 18157,
#  'Porpué': 14431,
#  'desafio': 12640,
#  'drift…': 25203,
#  'arquitectura': 4868,
#  'aberracion': 18714,
#  'entrevistas': 3820,
#  'sarna': 27557,
#  'postura': 19823,
#  'Empedandome': 27007,
#  '😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭': 24041,
#  'ALGO': 17715,
#  'sobremanera': 26544,
#  'mostrando': 7045,
#  'gorda': 862,
#  'KERNERISTAS': 12992,
#  'positivismo': 4921,
#  'marrana': 24741,
#  'hechos': 17816,
#  'Chacín': 12200,
#  'orale': 8505,
#  'triunfando': 25978,
#  '365días': 26892,
#  'ROLES': 11337,
#  'editada': 26454,
#  'libertad': 934,
#  'polla😏': 13033,
#  'Whiskey': 14484,
#  'corredores': 23024,
#  'Confio': 11594,
#  'personas': 170,
#  'articulos': 28350,
#  'suéter': 9570,
#  'diez': 5932,
#  'contrario': 5137,
#  'mejooor': 26729,
#  'natación': 6005,
#  'Emisión': 14115,
#  'activado': 9494,
#  'Revolución': 27424,
#  'camila': 7735,
#  'suspensión': 8534,
#  'neutro': 26746,
#  'Sé': 3216,
#  'resfrie': 9853,
#  'aye': 10880,
#  'burda': 19423,
#  'ignoras:': 18867,
#  'cren': 8933,
#  'humedal': 18476,
#  'dominicanos': 28353,
#  'TOMATELA': 29427,
#  'tapones': 7757,
#  'CANCIÓN': 9272,
#  'desmayó': 21041,
#  'transbarca': 14704,
#  'papis': 14879,
#  'feina': 10809,
#  'sea': 173,
#  'criticarte': 20663,
#  'mdp': 12565,
#  'Maite': 19650,
#  'noel': 12935,
#  'MeLaPelaLaCela': 11298,
#  'kim': 24638,
#  'TeVasPorqueTeOdian': 24462,
#  'analizar': 9381,
#  'convencer': 18353,
#  'desesperante': 11970,
#  'regalan': 14869,
#  'PUES': 13483,
#  'sentarme': 8280,
#  'versatilidad': 16934,
#  'NationalShortGirlDay': 10447,
#  'Gomez': 6407,
#  'contando': 1965,
#  'dibujó': 28769,
#  'extra': 4429,
#  'inflados': 23700,
#  '😇': 5513,
#  'huracanes': 18115,
#  'topical': 19673,
#  'Valeria': 16126,
#  'el': 8,
#  'This': 9808,
#  '—Profe': 17731,
#  'CastaPolitica': 18381,
#  'políticas': 9032,
#  'saludan': 26299,
#  'Editoriales': 25490,
#  'casitas': 27087,
#  'manda': 1045,
#  'eah': 14346,
#  'plan': 937,
#  'tempos': 18410,
#  'PORQUERIA': 24189,
#  'Cobain': 11263,
#  'sesión': 7396,
#  'AustinForMMVA': 24922,
#  'PLAY': 25211,
#  'parecemos': 23478,
#  'preparaba': 10420,
#  'Auxiliador': 13291,
#  'inconstitucionalitat': 22570,
#  'Ahtletic': 12775,
#  'irán': 8578,
#  'sabe': 246,
#  'Televisa': 4966,
#  'RobanCon': 19736,
#  'trabajadores': 3587,
#  'camuflajea': 22239,
#  'machista': 5473,
#  'vezz': 26900,
#  'Sabina': 9111,
#  'MAMMMMMMÁ': 13896,
#  'NoQuería': 20270,
#  'Zapata': 3850,
#  'respondí': 20027,
#  'realista': 24397,
#  'Permiso': 16782,
#  'comio': 23164,
#  'interrumpiéndolo': 12051,
#  'mutamos': 23020,
#  'LastimaQueSeAcabo': 18741,
#  'weones': 28417,
#  'Bo': 27349,
#  'nCuando': 2384,
#  'riquisimo': 18147,
#  '6000': 15383,
#  'zarpadoo': 28331,
#  'andará¿': 23161,
#  'hagarraron': 15869,
#  'consiga': 12618,
#  'nSeguiraElBullying': 21952,
#  '—El': 10836,
#  'hastaloshuevosyacabadeempezar': 15977,
#  '¿poquito': 18744,
#  'novio/a': 20290,
#  'ascodetradiciones': 20133,
#  'oscar': 7587,
#  'Ortega': 5034,
#  '👩\u200d❤️\u200d💋\u200d👩✋🏼✋🏼✋🏼': 26026,
#  'correcta': 5101,
#  'Netflix': 5477,
#  'están': 226,
#  'caminara': 23485,
#  'lyrics': 23326,
#  'brillosita': 19146,
#  'RRPP': 14198,
#  'polémico': 16232,
#  'exponerlo': 19634,
#  'Pffff': 8920,
#  'jeje': 1746,
#  'UNE': 19794,
#  'podria': 2682,
#  'cargó': 23484,
#  'destapede': 18713,
#  'Asta': 25814,
#  'seguiria': 13110,
#  'colgar': 17702,
#  'sigut': 24180,
#  'enfrentamiento': 28506,
#  'criticar': 7927,
#  'Salir': 3688,
#  'hipo': 23928,
#  'resumenes': 27169,
#  'europea': 28340,
#  'BROS:': 20565,
#  'AppleWatch': 16674,
#  'TVAzteca': 10524,
#  'apretadera': 17153,
#  'educativa': 26499,
#  'OF': 17265,
#  'chauuu': 21843,
#  'demas💣': 24330,
#  'crecen': 9394,
#  'negocios': 7088,
#  'radiole': 26288,
#  'misa': 21445,
#  'MeMuero': 15245,
#  'calentitaporcojones': 14709,
#  'hombrada': 26334,
#  'medición': 28788,
#  'mary': 16255,
#  'Dama': 17466,
#  'adoptar': 11120,
#  'beef': 27813,
#  'ElChiringuitoDeNeox': 25877,
#  'asustando': 9929,
#  'posts': 12535,
#  'escatológica': 26202,
#  'Todas': 23496,
#  'fapuv': 12654,
#  'deprimentes': 6323,
#  'amanecer': 6075,
#  'llegues': 3641,
#  'finalmente': 4425,
#  'IF': 16052,
#  'granaderos': 25833,
#  'facundo': 19166,
#  'corruptos': 2019,
#  'Amorebieta': 11046,
#  'cristales': 15522,
#  'Wall': 12885,
#  'expresiva': 22300,
#  'tirar': 1567,
#  'difamar': 24428,
#  'preocupe': 3630,
#  'Estrella': 9138,
#  'descargan': 29648,
#  'sintió': 6026,
#  'pajeros': 24892,
#  'ciertos': 5399,
#  'friito': 12367,
#  'SoberaniaAlimentaria': 15966,
#  'haci': 9798,
#  'pies': 2729,
#  'evidentemente': 8834,
#  'ligero': 7276,
#  'inclino': 9880,
#  'Gana': 22280,
#  'ahii': 18106,
#  'cuchaste': 25942,
#  'oraciones': 10407,
#  'casas': 2465,
#  '😒😭brackets': 28116,
#  'tannnto': 20065,
#  'Despertarse': 23828,
#  'Paulina': 4394,
#  'chocolate': 1191,
#  'mandarle': 29282,
#  'Esquivel': 7290,
#  'luce': 5817,
#  'pensé': 1249,
#  'responderé:': 26885,
#  'debate': 5204,
#  'quitasen': 13708,
#  'Ronaldo': 26726,
#  'charlatán': 25562,
#  'VotaPAN': 24278,
#  'comería': 25255,
#  'Esponja': 28334,
#  'pintados': 28720,
#  'dejé': 9797,
#  'Kiba': 27227,
#  'vive': 1328,
#  'nacionales': 6956,
#  'lopez': 6693,
#  'migue': 23736,
#  'acondicionado': 3643,
#  'Callejones': 28218,
#  'aplican': 5205,
#  'Agotados': 19122,
#  '60€': 25580,
#  'Asueto': 23514,
#  'trabajodeef': 18786,
#  'Hacé': 23578,
#  'falsedad': 5527,
#  '60x60': 27437,
#  'pidiendome': 27843,
#  'cortooo': 18114,
#  'juisteeeeee': 13228,
#  'democracia': 1245,
#  'NI': 3462,
#  'sanos': 29742,
#  'mande': 4191,
#  'cantera': 21197,
#  'Ruso': 15802,
#  'ayuno': 26016,
#  'Jajá': 25464,
#  'adulta': 9669,
#  'rápido⏳': 23255,
#  'intrascendentes': 23693,
#  'ahorita': 1854,
#  'Marina': 27538,
#  'cambiado': 1949,
#  'deseosa': 5179,
#  'negros': 3545,
#  'avinguts': 16369,
#  'mostramos': 21454,
#  'buffalo': 13805,
#  'elaboración': 11729,
#  'veres': 8671,
#  'chorbo': 24580,
#  'Nieto': 23868,
#  'burbuja': 7214,
#  'Chuo': 15901,
#  'Disfruta': 8052,
#  'Día:': 7123,
#  'conversaciones': 2804,
#  'dramaa': 28194,
#  'Casualida': 17071,
#  'Inmenso': 19539,
#  'Paga': 14963,
#  'desmentidos': 25186,
#  'Bultos': 25815,
#  'noquierolluvia': 25454,
#  'cambiarse': 23468,
#  'Cadiz': 9469,
#  'Yeiiihhhhh': 17111,
#  'NUNCA': 2999,
#  'vaina': 1539,
#  'conviene': 14774,
#  'arcos': 20758,
#  'rozaremos': 28300,
#  'menudas': 23834,
#  'Biiieen': 25010,
#  'hellow': 10392,
#  'humildes': 7574,
#  'indirectas': 3505,
#  'division': 12614,
#  'Invertimos': 28694,
#  'muchoestabatardando': 14490,
#  'resto': 1040,
#  'braces': 26569,
#  'habiendo': 19613,
#  'Game': 4136,
#  'lel': 11463,
#  'deberías': 2625,
#  'soledad': 1687,
#  'Tele': 22685,
#  'baches': 17453,
#  'creí': 2435,
#  'fragil': 10267,
#  '😔😔😢😞BienvenidoJulio': 14283,
#  'Buagg': 19615,
#  'fallas': 5801,
#  'J': 4489,
#  'pachonsito': 12970,
#  'Baby': 4197,
#  '¡Para': 26735,
#  'cauen': 26768,
#  '😍✋😏': 28948,
#  'FESC': 21650,
#  'indescriptibles': 22783,
#  'ceremonias': 12183,
#  '🐽🐽🐽jajja': 28648,
#  '💤💤dormir': 15630,
#  'publicacion': 8845,
#  'poquitoMUCHO': 16637,
#  'sola😡😠': 27493,
#  'jodiste': 24433,
#  'tocava': 15517,
#  'JAJAJAJA': 1136,
#  'delincuentes': 7374,
#  'estudiante': 4065,
#  'escucharé': 23685,
#  'exfoliacion': 18841,
#  'intentad': 23607,
#  'WhatsApp': 2067,
#  'tía': 1728,
#  'indios': 29591,
#  'catalanes': 18547,
#  'inmundo': 19435,
#  'calentador': 19553,
#  'ideario': 24828,
#  'castigo': 5746,
#  'facilota': 29044,
#  'librito': 26032,
#  'hise': 12515,
#  'quedasteee': 10460,
#  'aburra': 28056,
#  'sorprenden': 29158,
#  'ilusión😞': 19843,
#  'físicamente': 20300,
#  ":'D": 5130,
#  'Guaymas': 23966,
#  'amargarte': 10256,
#  'bien😞': 12414,
#  'Jugador': 8174,
#  'heart': 14921,
#  'mp3': 10327,
#  'estadounidense': 7265,
#  'tal': 367,
#  'jajai': 11726,
#  'Norteamérica': 21188,
#  'kiere': 9647,
#  'paloma:': 12267,
#  'FAVS': 20723,
#  'condones': 16817,
#  'don': 2100,
#  'deajr': 18631,
#  'nLa': 4096,
#  'pitufos': 5726,
#  'BuenJueves': 13196,
#  'vieneo': 13146,
#  'tercera': 6228,
#  'Stalkear': 11126,
#  'jamas': 1344,
#  'consciencia': 10850,
#  'diaaaaa': 28161,
#  'tarde/noche': 21849,
#  "90's": 9297,
#  '¡Muchas': 12359,
#  '💶🙌🍺🌅': 23836,
#  'y': 6,
#  'USHUAIA': 17075,
#  'kioscos': 21932,
#  'dolieron': 16830,
#  'crayon': 11573,
#  'FAMILIA': 3464,
#  'solteros': 11225,
#  'Tv': 21571,
#  'asiendo': 10064,
#  'garrison': 11483,
#  '4k': 18357,
#  'vacias': 10043,
#  'fajes': 28616,
#  'ladelamalasuerte': 28752,
#  'Destinomorales': 24885,
#  'quitan': 3551,
#  'avispa': 9034,
#  'tendones': 24779,
#  'Bayamón': 18846,
#  'estoyhastalapolla': 28001,
#  'rojos': 26678,
#  'vida😍': 23414,
#  'Agradecemos': 7889,
#  'casadas': 21018,
#  'Inversión': 20668,
#  'revive': 23133,
#  'confieso': 16518,
#  'pendejitas': 15627,
#  'desafioindia': 13523,
#  'Llevó': 11940,
#  'individual': 12961,
#  'Entra': 15837,
#  'vesemo': 11000,
#  'irreparable': 18779,
#  'nOk': 7343,
#  'retrasandose': 19204,
#  'surtido': 22936,
#  'level': 5392,
#  'coloco': 17825,
#  'Esos': 1274,
#  'sigas': 4016,
#  'cuánto': 8971,
#  'desaparecido': 10554,
#  'Noo': 21203,
#  'peores': 4704,
#  'guarnición': 28464,
#  'llevar': 970,
#  'matica': 26241,
#  'Guardiola': 3278,
#  'diversionen4ruedas': 22824,
#  'Miren': 3786,
#  'heredarme': 15023,
#  'karaoke': 18596,
#  'kemestasdiciendoo': 22552,
#  'MenosMal': 10057,
#  'incesto': 7752,
#  'estarlo': 28318,
#  'Banca': 7629,
#  'añitos': 22284,
#  'eléctrica': 4770,
#  'pizza': 2222,
#  'PIEZA': 18455,
#  'Aumenta': 19866,
#  'Ariana': 14816,
#  'cerrar': 1961,
#  'alegra': 1756,
#  'Jjajaajjaa': 16882,
#  'Capo': 6857,
#  'Isaác': 10129,
#  'espíritu': 6665,
#  'fotoooos': 25680,
#  'charlie': 2265,
#  'vendrá': 3146,
#  'anginas': 24954,
#  'drama': 4962,
#  'fueron': 1201,
#  'humillarme': 15139,
#  'harta': 5491,
#  'fanpage': 12361,
#  'quemas': 15872,
#  'donofrio': 28371,
#  'ud': 1855,
#  'unidad': 6738,
#  'bajenme': 18932,
#  'matutino': 17934,
#  '¡¡¡Sorpresaaaaaa': 16583,
#  'concuerda': 19962,
#  '😱😱😱😱': 21265,
#  'OhMaiGosh': 19247,
#  'alcanza': 6769,
#  'madrina': 10981,
#  'Olvidaba': 16931,
#  'YaBasta': 25439,
#  'AR': 12343,
#  'weas': 12084,
#  'Pantoja': 7056,
#  'enojan': 7521,
#  'gobernadora': 13122,
#  'doliendo': 19216,
#  'dale': 2959,
#  'vuelto': 2525,
#  'olvidando': 3937,
#  'describe': 18701,
#  'golubovic': 14290,
#  'feitos': 17142,
#  'funcionan': 4729,
#  'respetan': 25693,
#  'darnos': 5484,
#  'BORRACHA': 7432,
#  'SiaLosTorosEnTVE': 8114,
#  'perrie': 21959,
#  'JAULA': 21439,
#  'Precio': 17423,
#  'querais': 25080,
#  'aplicaría': 10146,
#  'hotelero': 27171,
#  'ingensta': 14060,
#  'Grey': 7013,
#  'obliguen': 29058,
#  'babeadas': 19837,
#  'paraguayo': 15687,
#  'bronceé': 16529,
#  'los': 20,
#  'Leona': 18906,
#  'Agujetas': 18346,
#  'Volarse': 21011,
#  'Gatito': 7548,
#  'productivos': 16609,
#  'Lol': 8978,
#  'manchemos': 15108,
#  'actualización': 6759,
#  'Backstreet': 15201,
#  'Olvidadme': 29492,
#  'Aldana': 7058,
#  'cuantos': 2091,
#  'simpática': 2547,
#  'León': 3082,
#  'Cree': 8949,
#  'recuerden': 19558,
#  'cantaron': 7326,
#  'Extremadura': 29186,
#  'vieran': 23379,
#  'galería': 7625,
#  'netflix': 24100,
#  'macro': 15244,
#  'motivado': 9600,
#  'veranito': 10530,
#  'cobardes': 8544,
#  'cardíaco': 17888,
#  'Diaz': 14215,
#  'mufa': 8691,
#  'contenidos': 11769,
#  'CREE': 27430,
#  ...}

# %%
token.word_counts
# Out:
# OrderedDict([('Tengo', 72),
#              ('tantas', 41),
#              ('ganas', 146),
#              ('de', 5963),
#              ('comer', 40),
#              ('sopa', 3),
#              ('@', 4939),
#              ('faltó', 7),
#              ('el', 3052),
#              ('ingenioso', 1),
#              ('😅', 5),
#              ('donde', 270),
#              ('sea', 119),
#              ('pero', 619),
#              ('que', 6335),
#              ('se', 1834),
#              ('le', 573),
#              ('caiga', 7),
#              ('pipi', 1),
#              ('charlie', 7),
#              ('Yo', 208),
#              ('ya', 549),
#              ('te', 1341),
#              ('sigo', 40),
#              ('me', 2926),
#              ('gustan', 29),
#              ('y', 3344),
#              ('tus', 93),
#              ('fotos', 65),
#              ('video', 34),
#              ('hace', 282),
#              ('poco', 112),
#              ('genialisimo', 1),
#              ('ON', 9),
#              ('Ah', 34),
#              ('bueno', 210),
#              ('si', 891),
#              ('respuesta', 33),
#              ('jajajajaja', 45),
#              ('Partidazo', 2),
#              ('Noir', 1),
#              ('como', 2122),
#              ('es', 2146),
#              ('descubren', 1),
#              ('eso', 345),
#              ('ahora', 226),
#              ('Más', 15),
#              ('Pymes', 1),
#              ('cómo', 103),
#              ('habrá', 23),
#              ('enterado', 6),
#              ('todos', 264),
#              ('necesitamos', 6),
#              ('un', 1523),
#              ('portasandia', 1),
#              ('en', 2942),
#              ('la', 3969),
#              ('vida', 349),
#              ('negociazo', 1),
#              ('http://link', 2658),
#              ('Hablar', 2),
#              ('Con', 98),
#              ('El', 348),
#              ('Como', 433),
#              ('Lo', 201),
#              ('Mas', 20),
#              ('Hermoso', 10),
#              ('Que', 936),
#              ('Hay', 59),
#              ('Entiende', 2),
#              ('Mis', 31),
#              ('Visajes', 1),
#              ('Y', 442),
#              ('Los', 118),
#              ('De', 134),
#              ('♡', 8),
#              ('Hablemos', 2),
#              ('con', 1327),
#              ('Representante', 1),
#              ('responde', 8),
#              ('al', 581),
#              ('pueblo', 39),
#              ('Adoro', 11),
#              ('gente', 268),
#              ('critica', 6),
#              ('tarde', 101),
#              ('mas', 479),
#              ('productiva', 6),
#              ('Xq', 7),
#              ('ponen', 23),
#              ('a', 4085),
#              ('gritar', 3),
#              ('los', 1344),
#              ('vecinos', 17),
#              ('esta', 1447),
#              ('hora', 198),
#              ('Ir', 7),
#              ('iglesia', 4),
#              ('noche', 194),
#              ('hizo', 45),
#              ('bien', 649),
#              ('Mami', 4),
#              ('está', 428),
#              ('haciendo', 71),
#              ('domplines', 1),
#              ('👅', 1),
#              ('Ni', 38),
#              ('mierda', 108),
#              ('Quiero', 43),
#              ('exámenes', 26),
#              ('sean', 30),
#              ('hoy', 247),
#              ('cinco', 6),
#              ('horas', 91),
#              ('duración', 1),
#              ('256', 1),
#              ('encantas', 5),
#              ('eres', 127),
#              ('sientete', 1),
#              ('dichoso', 1),
#              ('jaja', 110),
#              ('caes', 13),
#              ('super', 55),
#              ('mua', 2),
#              ('Gracias', 204),
#              ('por', 1726),
#              ('lo', 1540),
#              ('deseen', 1),
#              ('para', 1183),
#              ('mi', 1228),
#              ('familia', 68),
#              ('Dios', 96),
#              ('multiplique', 1),
#              ('No', 653),
#              ('hay', 384),
#              ('quien', 444),
#              ('pare', 9),
#              ('J', 3),
#              ('Alvarez', 1),
#              ('Ft', 1),
#              ('Tito', 2),
#              ('Bambino', 1),
#              ('Pero', 130),
#              ('filo', 1),
#              ('tenemos', 64),
#              ('copa', 25),
#              ('américa', 3),
#              ('importa', 65),
#              ('resto', 17),
#              ('bazzinga', 2),
#              ('CopaAmerica', 2),
#              ('lindo', 137),
#              ('fue', 229),
#              ('llegar', 59),
#              ('depto', 1),
#              ('sintiendome', 1),
#              ('mal', 242),
#              ('este', 1009),
#              ('mami', 5),
#              ('😁', 27),
#              ('bonus', 1),
#              ('track', 2),
#              ('Porque', 146),
#              ('yo', 575),
#              ('no', 3144),
#              ('quiero', 244),
#              ('trabajar', 65),
#              ('ir', 203),
#              ('estudiar', 92),
#              ('casarrrrrr♪♫', 1),
#              ('he', 133),
#              ('todo', 560),
#              ('claro', 105),
#              ('profesor', 6),
#              ('su', 370),
#              ('sueldo', 13),
#              ('riquezas', 1),
#              ('porque', 860),
#              ('ama', 25),
#              ('puta', 84),
#              ('foto', 77),
#              ('odia', 4),
#              ('mínimo', 3),
#              ('subirla😂', 1),
#              ('Arreglarme', 1),
#              ('nada', 361),
#              ('más', 527),
#              ('gusta', 188),
#              ('fracaso', 7),
#              ('gracias', 173),
#              ('empeño', 2),
#              ('pusieron', 3),
#              ('nota', 65),
#              ('mataron', 7),
#              ('cancha', 11),
#              ('son', 322),
#              ('mejores', 60),
#              ('del', 985),
#              ('área', 3),
#              ('245', 2),
#              ('Favoritos', 7),
#              ('Tu', 70),
#              ('tuit', 22),
#              ('ha', 225),
#              ('sido', 54),
#              ('marcado', 10),
#              ('favorito', 13),
#              ('personas', 126),
#              ('Mujer', 4),
#              ('pervertida', 1),
#              ('vale', 36),
#              ('dos', 117),
#              ('o', 307),
#              ('era', 141),
#              ('Escóndete', 1),
#              ('silencio', 16),
#              ('aquí', 96),
#              ('podrás', 4),
#              ('volver', 36),
#              ('ApocalipsisNeoliberal', 2),
#              ('Felipe', 8),
#              ('Glez', 1),
#              ('harán', 6),
#              ('campaña', 8),
#              ('favor', 93),
#              ('Me', 772),
#              ('resfrie', 1),
#              ('poquito', 24),
#              ('Solo', 32),
#              ('dinah', 1),
#              ('puede', 147),
#              ('demorar', 1),
#              ('tanto', 186),
#              ('escribirle', 1),
#              ('algo', 233),
#              ('normani', 1),
#              ('DINAH', 1),
#              ('aceptamos', 1),
#              ('Te', 141),
#              ('esperaré', 1),
#              ('nadie', 113),
#              ('note', 8),
#              ('haces', 36),
#              ('falta', 69),
#              ('n', 220),
#              ('dormiré', 2),
#              ('trajo', 4),
#              ('cuando', 1200),
#              ('embarazada', 6),
#              ('Bien', 43),
#              ('gallina', 2),
#              ('va', 362),
#              ('tocar💜', 1),
#              ('Extendieron', 263),
#              ('las', 1831),
#              ('primarias', 265),
#              ('Psuv', 263),
#              ('hasta', 427),
#              ('10', 328),
#              ('pm', 263),
#              ('gentío', 263),
#              ('colas', 267),
#              ('FollowBackSeguro', 7),
#              ('Cada', 34),
#              ('vez', 216),
#              ('llega', 33),
#              ('E3', 2),
#              ('lloro', 15),
#              ('dentro', 17),
#              ('puedo', 147),
#              ('estar', 178),
#              ('ahí', 71),
#              ('deseo', 20),
#              ('una', 891),
#              ('fuerza', 14),
#              ('tremenda', 9),
#              ('Diosmeama', 1),
#              ('Es', 255),
#              ('milésima', 1),
#              ('intentas', 4),
#              ('tratarme', 3),
#              ('mejor', 418),
#              ('nunca', 158),
#              ('pasa', 133),
#              ('͡°', 2),
#              ('pito', 3),
#              ('democracia', 14),
#              ('transparencia', 4),
#              ('rendición', 1),
#              ('cuentas', 13),
#              ('votar', 56),
#              ('café', 10),
#              ('Oxxo', 1),
#              ('😝', 7),
#              ('tiene', 587),
#              ('12', 20),
#              ('años', 108),
#              ('ese', 130),
#              ('nene', 9),
#              ('explique', 4),
#              ('usted', 52),
#              ('dice', 86),
#              ('Caos', 1),
#              ('propone', 2),
#              ('político', 21),
#              ('transparente', 3),
#              ('país', 82),
#              ('17', 5),
#              ('días', 106),
#              ('yupi', 3),
#              ('Hermanita', 1),
#              ('muchas', 35),
#              ('x', 61),
#              ('acompañarme', 1),
#              ('espera', 38),
#              ('después', 84),
#              ('taquitos', 2),
#              ('TQM', 1),
#              (':', 328),
#              ('Tres', 39),
#              ('prórrogas', 38),
#              ('Esa', 28),
#              ('satisfacción', 4),
#              ('poder', 76),
#              ('hacerte', 14),
#              ('feliz', 106),
#              ('tener', 185),
#              ('esperar', 46),
#              ('carajo', 16),
#              ('Uffff', 2),
#              ('delicia', 4),
#              ('apesarde', 1),
#              ('felizdomingo', 1),
#              ('Cuando', 285),
#              ('vive', 13),
#              ('fidelidad', 1),
#              ('grandes', 37),
#              ('cosas', 204),
#              ('vendrán', 2),
#              ('Este', 134),
#              ('yixing', 3),
#              ('maldito', 8),
#              ('lleva', 17),
#              ('camisa', 6),
#              ('solo', 239),
#              ('chaqueta', 1),
#              ('además', 14),
#              ('abotonada', 1),
#              ('//', 12),
#              ('gesto', 1),
#              ('tan', 497),
#              ('afeminado', 1),
#              ('Deidara', 1),
#              ('La', 350),
#              ('muy', 294),
#              ('corta', 16),
#              ('atado', 1),
#              ('alguien', 151),
#              ('sí', 93),
#              ('ombre', 1),
#              ('inclino', 1),
#              ('Giammattei', 1),
#              ('menos', 147),
#              ('peor', 54),
#              ('tengo', 345),
#              ('mis', 186),
#              ('dudas', 7),
#              ('todavía', 29),
#              ('Aun', 7),
#              ('leído', 10),
#              ('plan', 19),
#              ('gobierno', 34),
#              ('aunque', 29),
#              ('ni', 286),
#              ('veces', 97),
#              ('suspiro', 1),
#              ('bolillero', 1),
#              ('ser', 379),
#              ('certero', 1),
#              ('entre', 68),
#              ('entrevero', 1),
#              ('dar', 62),
#              ('giro', 3),
#              ('Parqueo', 2),
#              ('completo', 8),
#              ('hicieron', 17),
#              ('Traficocr', 2),
#              ('via', 17),
#              ('abran', 1),
#              ('piscina', 10),
#              ('tiempo', 147),
#              ('esté', 12),
#              ('así', 251),
#              ('suerte', 89),
#              ('😊😊😊😊😊', 1),
#              ('bandejita', 1),
#              ('lomo', 2),
#              ('choclo', 1),
#              ('fréjol', 1),
#              ('spaghetti', 1),
#              ('carbonara', 1),
#              ('langosta:', 1),
#              ('mundo', 161),
#              ('derecho', 23),
#              ('progresar', 2),
#              ('pobre', 20),
#              ('👇', 1),
#              ('exacto', 3),
#              ('mio', 36),
#              ('maravilla', 16),
#              ('destinomorales', 9),
#              ('piensa', 23),
#              ('hacer', 268),
#              ('monopolios', 2),
#              ('tv', 11),
#              ('ejemplo', 31),
#              ('¡En', 1),
#              ('firmamento', 1),
#              ('están', 91),
#              ('celosas', 1),
#              ('estrellas', 15),
#              ('tierra', 18),
#              ('tú', 54),
#              ('bella', 14),
#              ('anda', 31),
#              ('twitter', 37),
#              ('Si', 279),
#              ('sucia', 3),
#              ('quedaría', 3),
#              ('agua', 44),
#              ('zanja', 2),
#              ('MeChamuyaronDiciendo', 1),
#              ('amo', 106),
#              ('vos', 129),
#              ('teniendo', 11),
#              ('otra', 120),
#              ('cama', 35),
#              ('Jaja', 20),
#              ('ante', 26),
#              ('Sí', 33),
#              ('Sobre', 7),
#              ('Patilla', 2),
#              ('soy', 228),
#              ('forra', 4),
#              ('hablen', 3),
#              ('les', 156),
#              ('insistan', 1),
#              ('estoy', 273),
#              ('bancar', 2),
#              ('giladas', 3),
#              ('😊', 36),
#              ('Toda', 11),
#              ('esperado', 3),
#              ('Café', 2),
#              ('Tacvba', 1),
#              ('presente', 18),
#              ('Bogotá', 9),
#              ('sueño', 91),
#              ('hecho', 65),
#              ('realidad', 28),
#              ('Quien', 86),
#              ('manda', 17),
#              ('dormir', 198),
#              ('siesta', 11),
#              ('Miller', 1),
#              ('Díaz', 3),
#              ('Chope', 4),
#              ('volvimos', 2),
#              ('vergüenza', 15),
#              ('mundial', 18),
#              ('estábamos', 4),
#              ('acostumbrados', 2),
#              ('Selección', 1),
#              ('Domingo', 9),
#              ('Lindo', 13),
#              ('día', 330),
#              ('empezar', 57),
#              ('Estaban', 2),
#              ('vestidos', 4),
#              ('usaron', 1),
#              ('Miss', 2),
#              ('Unica', 1),
#              ('😂😂', 50),
#              ('Eh', 10),
#              ('hacerse', 2),
#              ('loco', 43),
#              ('mente', 20),
#              ('na', 13),
#              ('pierdo', 10),
#              ('encanta', 406),
#              ('noches', 51),
#              ('pensar', 50),
#              ('debería', 22),
#              ('ver', 281),
#              ('echo', 10),
#              ('hize', 1),
#              ('😧', 2),
#              ('Jenny', 2),
#              ('seduciendo', 2),
#              ('💞💞', 1),
#              ('👇👇👇', 1),
#              ('—', 100),
#              ('eh', 113),
#              ('cuerpazo', 1),
#              ('divino', 7),
#              ('andas', 13),
#              ('mismo', 92),
#              ('pensé', 14),
#              ('momento', 105),
#              ('habló', 2),
#              ('sus', 186),
#              ('palabras', 43),
#              ('había', 51),
#              ('honor', 6),
#              ('verdad', 132),
#              ('modo', 15),
#              ('Jon', 2),
#              ('Snow', 1),
#              ('😪', 8),
#              ('monotonía', 1),
#              ('nos', 261),
#              ('sepando', 1),
#              ('nMe', 9),
#              ('siento', 95),
#              ('cansada', 7),
#              ('😩', 13),
#              ('bonito', 86),
#              ('vestido', 6),
#              ('Anais', 1),
#              ('límite', 4),
#              ('derechos', 10),
#              ('encuentra', 6),
#              ('lastimas', 1),
#              ('d', 86),
#              ('demás', 35),
#              ('PRD', 9),
#              ('Cabos', 1),
#              ('desquició', 1),
#              ('comunicación', 7),
#              ('carretera', 5),
#              ('impunemente', 1),
#              ('Se', 147),
#              ('quedado', 11),
#              ('buena', 150),
#              ('semana', 161),
#              ('Epa', 1),
#              ('Mario', 12),
#              ('Silva', 4),
#              ('acuerdo:', 1),
#              ('tipo', 46),
#              ('seguro', 73),
#              ('Derecha', 1),
#              ('Por:', 2),
#              ('Florencia', 1),
#              ('Herrera', 5),
#              ('corruptos', 8),
#              ('trago', 2),
#              ('victoria', 7),
#              ('logros', 1),
#              ('conseguidos', 1),
#              ('Bolivia', 4),
#              ('Todo', 74),
#              ('playa', 25),
#              ('wiii', 4),
#              ('re', 148),
#              ('bardea', 1),
#              ('jajjaja', 3),
#              ('Un', 112),
#              ('TodoSeaPorAprobar', 1),
#              ('Mejor', 19),
#              ('Amigo', 2),
#              ('Vaya', 39),
#              ('mía', 19),
#              ('JAJAJAJAAJAJAJAJAJAJAAJAJAJA', 1),
#              ('Esta', 214),
#              ('angelita', 4),
#              ('caida', 4),
#              ('cielo', 21),
#              ('buscando', 14),
#              ('amigo', 67),
#              ('encuentras', 9),
#              ('aqui', 53),
#              ('gt', 80),
#              ('estacionar', 1),
#              ('auto', 12),
#              ('gral', 1),
#              ('Paz', 6),
#              ('Panamericana', 2),
#              ('Espero', 21),
#              ('hermana', 21),
#              ('eche', 2),
#              ('jajajajajajajajajajaja', 1),
#              ('pasando', 45),
#              ('The', 11),
#              ('1975', 3),
#              ('asustando', 1),
#              ('Eso', 55),
#              ('beber', 7),
#              ('2lts', 2),
#              ('diario', 15),
#              ('simple', 8),
#              ('mercadotecnia', 1),
#              ('puedes', 35),
#              ('hidratar', 1),
#              ('haciéndote', 1),
#              ('sobre', 89),
#              ('tang', 1),
#              ('lol', 15),
#              ('sé', 111),
#              ('cuanto', 17),
#              ('durar', 2),
#              ('Sólo', 15),
#              ('dejame', 2),
#              ('sentir', 28),
#              ('rato', 22),
#              ('esto', 174),
#              ('tenerlo', 4),
#              ('necesitar', 3),
#              ('Jajajaja', 38),
#              ('ve', 76),
#              ('burgi', 1),
#              ('Sino', 3),
#              ('tambien', 27),
#              ('saca', 13),
#              ('jajajajajajja', 2),
#              ('tenéis', 5),
#              ('repetir', 5),
#              ('poner', 53),
#              ('vídeo', 15),
#              ('viaje', 24),
#              ('Italia', 4),
#              ('manu', 1),
#              ('aún', 37),
#              ('hemos', 17),
#              ('visto', 66),
#              ('😒😤', 1),
#              ('myhyv', 4),
#              ('TronoChicas', 2),
#              ('Por', 163),
#              ('todas', 91),
#              ('esas', 66),
#              ('Bob', 3),
#              ('marley', 1),
#              ('imagino', 15),
#              ('tio', 6),
#              ('apuntando', 1),
#              ('frases', 9),
#              ('luego', 45),
#              ('ponerlas', 1),
#              ('notecreasnada', 1),
#              ('decir', 87),
#              ('cursis', 1),
#              ('hago', 57),
#              ('encerio', 4),
#              ('Las', 69),
#              ('redes', 15),
#              ('sociales', 17),
#              ('borran', 2),
#              ('datos', 13),
#              ('perfil', 15),
#              ('antes', 117),
#              ('salía', 3),
#              ('Ministra', 1),
#              ('Comunicación', 1),
#              ('Estrategia', 1),
#              ('Hilda', 1),
#              ('Hernández', 3),
#              ('raro', 73),
#              ('Está', 36),
#              ('Caliente', 1),
#              ('Mi', 189),
#              ('Facebook', 15),
#              ('xD', 59),
#              ('Qué', 165),
#              ('esperas', 8),
#              ('Personaliza', 1),
#              ('3', 124),
#              ('llaveros', 1),
#              ('ídolo', 4),
#              ('sólo', 62),
#              ('Enviamos', 1),
#              ('País', 4),
#              ('Whatsapp', 5),
#              ('0988001262', 1),
#              ('Pues', 62),
#              ('voy', 298),
#              ('series', 6),
#              ('linda', 42),
#              ('sos', 76),
#              ('Santa', 4),
#              ('Fe', 4),
#              ('estos', 70),
#              ('humedad', 5),
#              ('Sinceramente', 3),
#              ('preocupo', 3),
#              ('preocupe', 4),
#              (':D', 57),
#              ('qué', 289),
#              ('insistiendo', 2),
#              ('sinceramente', 2),
#              ('soñar', 11),
#              ('🎶', 20),
#              ('Hasta', 26),
#              ('despertas', 2),
#              ('7', 60),
#              ('am', 11),
#              ('salis', 1),
#              ('real', 17),
#              ('6°C', 1),
#              ('u', 42),
#              ('PPLI:', 1),
#              ('Felinos', 8),
#              ('Miranda', 11),
#              ('vencieron', 9),
#              ('domingo', 64),
#              ('Bucaneros', 8),
#              ('Guaira', 8),
#              ('Liga', 11),
#              ('Paralela', 6),
#              ('Baloncesto', 4),
#              ('NO', 92),
#              ('TE', 19),
#              ('TOCA', 3),
#              ('EN', 33),
#              ('BEATBOX', 2),
#              ('jajaja', 176),
#              ('buenísimo', 3),
#              ('Para', 54),
#              ('jueves', 18),
#              ('finde', 23),
#              ('Yooooooo', 1),
#              ('Jamas', 2),
#              ('😂😂😂', 44),
#              ('Les', 11),
#              ('juro', 17),
#              ('llorando', 12),
#              ('risa', 41),
#              ('nose', 27),
#              ('rio', 7),
#              ('rie', 5),
#              ('caro', 8),
#              ('paso', 61),
#              ('martina😂😂😂😁', 1),
#              ('mencionó', 1),
#              ('Coahuila', 2),
#              ('golden', 1),
#              ('age', 2),
#              ('revista', 3),
#              ('diga', 19),
#              ('boom', 7),
#              ('poblano', 1),
#              ('cuenta', 145),
#              ('dijo', 69),
#              ('juez', 2),
#              ('Hijo', 4),
#              ('desventaja', 2),
#              ('haber', 34),
#              ('aprendido', 5),
#              ('español', 10),
#              ('mucha', 40),
#              ('envidia', 16),
#              ('envidiosa', 2),
#              ('joder', 20),
#              ('😣😣', 3),
#              ('noviazgos', 2),
#              ('aparte', 6),
#              ('novios', 11),
#              ('frenes', 1),
#              ('cancion', 9),
#              ('incomparable', 1),
#              ('encantar', 2),
#              ('obtener', 1),
#              ('reacción', 2),
#              ('digan', 30),
#              ('g:', 2),
#              ('✋✋✋', 1),
#              ('sacabas', 2),
#              ('ponías', 1),
#              ('fav', 10),
#              ('vidilla', 1),
#              ('dais', 3),
#              ('tuiter', 3),
#              ('precio', 15),
#              ('seguid', 1),
#              ('Mordor', 1),
#              ('os', 39),
#              ('queda', 44),
#              ('pequeño', 6),
#              ('on', 18),
#              ('Mmm', 4),
#              ('madrugar', 17),
#              ('comeback', 2),
#              ('emoción', 32),
#              ('😞', 20),
#              ('bolsa', 9),
#              ('trabajo', 88),
#              ('aumentan', 2),
#              ('momentos', 41),
#              ('Uy', 18),
#              ('emocion', 7),
#              ('pibe', 20),
#              ('😒', 74),
#              ('estas', 144),
#              ('ausente', 3),
#              ('abrazo', 12),
#              ('guay', 43),
#              ('metro', 14),
#              ('Madrid', 67),
#              ('Berlín', 2),
#              ('bn', 6),
#              ('convenciste', 1),
#              ('fuer', 1),
#              ('Lopez', 1),
#              ('obrador', 1),
#              ('Creeré', 1),
#              ('ciegamente', 1),
#              ('q', 413),
#              ('dices', 21),
#              ('feas', 2),
#              ('cejas', 2),
#              ('delgadas', 1),
#              ('spaguetti', 1),
#              ('encantó', 3),
#              ('arbitraje', 2),
#              ('elegante', 3),
#              ('sofisticado', 1),
#              ('¡casi', 1),
#              ('perfecto', 33),
#              ('Tatuarse', 1),
#              ('costillas', 2),
#              ('sensación', 16),
#              ('bonita', 40),
#              ('Pitamos', 1),
#              ('Nadal', 2),
#              ('esperamos', 3),
#              ('próxima', 7),
#              ('derrota', 3),
#              ('decimos', 3),
#              ('retire', 1),
#              ('entusiasmado', 3),
#              ('debe', 56),
#              ('Chile', 20),
#              ('enfrentar', 1),
#              ('Argentina', 19),
#              ('CopaAmericaChile2015', 3),
#              ('historia', 40),
#              ('transporte', 4),
#              ('público', 11),
#              ('hermosa', 45),
#              ('chofer', 3),
#              ('108', 1),
#              ('bajar', 5),
#              ('pasó', 14),
#              ('finito', 1),
#              ('rubia', 3),
#              ('parte', 54),
#              ('cabeza', 106),
#              ('Encima', 6),
#              ('NticxHermoso', 1),
#              ('hermoso', 65),
#              ('sonó', 2),
#              ('despertador', 2),
#              ('creía', 3),
#              ('We', 5),
#              ('bronca', 21),
#              ('sal', 2),
#              ('Jajaj', 2),
#              ('¡¡¡No', 1),
#              ('dolor', 39),
#              ('Calor', 2),
#              ('deberías', 6),
#              ('maquillaje', 6),
#              ('tal', 53),
#              ('logras', 2),
#              ('auch', 1),
#              ('convulsionaste', 1),
#              ('Huevos', 1),
#              ('putos', 8),
#              ('✊', 3),
#              ('Jajaja', 62),
#              ('cierto', 36),
#              ('vean', 7),
#              ('creativa', 1),
#              ('pintarme', 2),
#              ('uñas', 7),
#              ('💅', 2),
#              ('Derroche', 1),
#              ('felicidad', 46),
#              ('tonterías', 5),
#              ('puse', 30),
#              ('juego', 41),
#              ('charly', 3),
#              ('moda', 12),
#              ('😏', 17),
#              ('Ahora', 71),
#              ('San', 32),
#              ('Antonio', 7),
#              ('preferencia', 2),
#              ('hacerle', 8),
#              ('venta', 3),
#              ('clientes', 4),
#              ('cada', 127),
#              ('enamoro', 9),
#              ('tienda', 4),
#              ('Bonita', 6),
#              ('excelente', 21),
#              ('descanso', 6),
#              ('nTe', 5),
#              ('amo❤😘', 1),
#              ('nY', 19),
#              ('siempre', 290),
#              ('contigo', 43),
#              ('tuyos', 5),
#              ('Maal', 1),
#              ('Perez', 4),
#              ('Acuña', 3),
#              ('bueno😍', 1),
#              ('13', 6),
#              ('concierto', 5),
#              ('Cantanhede', 1),
#              ('nerviosa', 8),
#              ('misión', 4),
#              ('OLP', 1),
#              ('actuando', 3),
#              ('duro', 19),
#              ('contra', 46),
#              ('hampa', 1),
#              ('Arepas', 1),
#              ('quier', 1),
#              ('😂😄', 1),
#              ('ponerme', 15),
#              ('ejercicios', 4),
#              ('acabar', 20),
#              ('tomate', 1),
#              ('Nooo', 8),
#              ('cerca', 19),
#              ('joderme', 3),
#              ('reciban', 2),
#              ('cara', 80),
#              ('culo', 20),
#              ('aburrida', 8),
#              ('piba', 9),
#              ('acabo', 20),
#              ('familiares', 6),
#              ('Haiti', 1),
#              ('😂😂😂😂', 15),
#              ('Ese', 30),
#              ('chabon', 13),
#              ('sube', 9),
#              ('misma', 33),
#              ('insta', 7),
#              ('dará', 7),
#              ('boludo', 8),
#              ('Ayer', 5),
#              ('di', 26),
#              ('elevado', 1),
#              ('nivel', 34),
#              ('ingles', 15),
#              ('😂', 92),
#              ('levante', 7),
#              ('pregunte', 1),
#              ('estaba', 69),
#              ('paz', 28),
#              ('😃', 8),
#              ('¿Por', 42),
#              ('has', 34),
#              ('terminado', 6),
#              ('irte', 7),
#              ('Oh', 41),
#              ('inteligencia', 10),
#              ('Su', 9),
#              ('IQ', 2),
#              ('otro', 89),
#              ('Vivan', 7),
#              ('enfermeras', 2),
#              ('majosas', 1),
#              ('Mf', 1),
#              ('mina', 18),
#              ('humor', 45),
#              ('TwOff', 1),
#              ('Dejen', 5),
#              ('sapos', 1),
#              ('loks', 1),
#              ('¿', 15),
#              ('Quién', 14),
#              ('blanco', 6),
#              ('fácil', 26),
#              ('inocente', 4),
#              ('creer', 28),
#              ('Soledad', 3),
#              ('canta', 11),
#              ('mismas', 7),
#              ('canciones', 23),
#              ('desde', 68),
#              ('ojo', 14),
#              ('alta', 14),
#              ('artista', 5),
#              ('guuuay', 1),
#              ('Somos', 10),
#              ('inocentes', 1),
#              ...])

# %%
print (token.word_index['@'])
print (token.word_index['http://link'])
# Out:
# 3
# 11

# %%
data['TWEET'] = data['TWEET'].apply(text2seq)

# %%
data.head()
# Out:
#   CATEGORY                                              TWEET
# 0        1                      [268, 456, 146, 2, 469, 4487]
# 1        1               [3, 3, 3, 3, 2263, 8, 9821, 3, 3047]
# 2        0  [3, 80, 173, 35, 1, 14, 39, 2264, 8, 9822, 226...
# 3        1  [3, 108, 41, 21, 470, 10, 660, 6, 216, 300, 6,...
# 4        1                 [3, 3, 559, 107, 29, 579, 29, 418]

# %%
pickle.dump(data,open('./tweet_seq.txt','wb'))

# %%
pickle.dump(token,open('./token.p','wb'))
